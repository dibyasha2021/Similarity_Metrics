# %%
#importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  # for plot styling
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
path = r"/content/drive/MyDrive/Project & Research /ISCAS-similarity/Clean Datased/final.csv"
data=pd.read_csv(path)

# %%
data=data.drop(columns=["Unnamed: 0"],axis=1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data
# Out:
#                                           description_x  \
# 0                        first trust dow jones internet
# 1                   schwab intl large company index etf
# 2                          vanguard small cap index adm
# 3     duke energy corp new com new isin #us4 sedol #...
# 4                                      visa inc class a
# ...                                                 ...
# 2137                            delta air lines inc com
# 2138                           cognizant tech solutns a
# 2139  pimco investment grade corporate bond fund - c...
# 2140                                 eli lilly & co com
# 2141                                dfa comm strategy i
#
#                                           description_y  Check  \
# 0                           first trust dj internet idx      1
# 1     schwab strategic tr fundamental intl large co ...      1
# 2                    vanguard small-cap index fund inst      0
# 3     duke energy corp new com new isin #us26441c204...      1
# 4                                             visa inc.      1
# ...                                                 ...    ...
# 2137                       delta air lines inc dela new      1
# 2138                      cognizant tech solutions corp      1
# 2139                  fid conservative income bond fund      0
# 2140                              lilly eli &co com npv      1
# 2141                        dfa commodity strategy port      1
#
#                                                   Dx,Dy  Cos_sim_bow  \
# 0     ['first trust dow jones internet', 'first trus...     0.600000
# 1     ['schwab intl large company index etf', 'schwa...     0.680414
# 2     ['vanguard small cap index adm', 'vanguard sma...     0.730297
# 3     ['duke energy corp new com new isin #us4 sedol...     0.833333
# 4                     ['visa inc class a', 'visa inc.']     0.816497
# ...                                                 ...          ...
# 2137  ['delta air lines inc com', 'delta air lines i...     0.730297
# 2138  ['cognizant tech solutns a', 'cognizant tech s...     0.577350
# 2139  ['pimco investment grade corporate bond fund -...     0.338062
# 2140    ['eli lilly & co com', 'lilly eli &co com npv']     0.894427
# 2141  ['dfa comm strategy i', 'dfa commodity strateg...     0.577350
#
#       Shepard_sim_bow  Min_Max_sim_bow  Cos_sim_TI  Shepard_sim_TI  \
# 0            0.135335         0.428571    0.431613        0.344316
# 1            0.106878         0.500000    0.527072        0.378117
# 2            0.176921         0.571429    0.580333        0.400056
# 3            0.135335         0.666667    0.716812        0.471149
# 4            0.367879         0.666667    0.709297        0.466499
# ...               ...              ...         ...             ...
# 2137         0.176921         0.571429    0.580333        0.400056
# 2138         0.176921         0.400000    0.411207        0.337846
# 2139         0.059106         0.200000    0.206137        0.283640
# 2140         0.367879         0.800000    0.818180        0.547154
# 2141         0.176921         0.400000    0.411207        0.337846
#
#       Min_Max_sim_TI
# 0           0.347953
# 1           0.348840
# 2           0.442176
# 3           0.587291
# 4           0.473355
# ...              ...
# 2137        0.442176
# 2138        0.286638
# 2139        0.136641
# 2140        0.635489
# 2141        0.286638
#
# [2142 rows x 10 columns]

# %%
data.describe()
# Out:
#              Check  Cos_sim_bow  Shepard_sim_bow  Min_Max_sim_bow  \
# count  2142.000000  2142.000000      2142.000000      2142.000000
# mean      0.753035     0.578507         0.186736         0.430630
# std       0.431347     0.235390         0.161536         0.229155
# min       0.000000     0.000000         0.016194         0.000000
# 25%       1.000000     0.408248         0.086338         0.250000
# 50%       1.000000     0.612372         0.135335         0.400000
# 75%       1.000000     0.755929         0.243117         0.600000
# max       1.000000     1.000000         1.000000         1.000000
#
#         Cos_sim_TI  Shepard_sim_TI  Min_Max_sim_TI
# count  2142.000000     2142.000000     2142.000000
# mean      0.454170        0.380152        0.326479
# std       0.237392        0.128207        0.200964
# min       0.000000        0.243117        0.000000
# 25%       0.260556        0.296385        0.176089
# 50%       0.450176        0.350413        0.286638
# 75%       0.632790        0.424441        0.442176
# max       1.000000        1.000000        1.000000

# %%
# Seperating the similarity values in table
CS_BOW=data.filter(["Check","Cos_sim_bow"], axis=1)
CS_BOW
# Out:
#       Check  Cos_sim_bow
# 0         1     0.600000
# 1         1     0.680414
# 2         0     0.730297
# 3         1     0.833333
# 4         1     0.816497
# ...     ...          ...
# 2137      1     0.730297
# 2138      1     0.577350
# 2139      0     0.338062
# 2140      1     0.894427
# 2141      1     0.577350
#
# [2142 rows x 2 columns]

# %% [markdown]
# Preprocessing and graphs

# %% [markdown]
# k- Nearest Neighborhood Evaluation

# %%
# nomalizing the the similarities

# libraries for preprocessing 
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split

# libraries for K NN classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix

# %%
X=CS_BOW['Cos_sim_bow']
y=CS_BOW['Check']
X1=X[np.newaxis,:]
y1=y[np.newaxis,:]
X1=X1.reshape(-1,1)
y1=y1.reshape(-1,1)

# %%
X1 =StandardScaler().fit(X1).transform(X1.astype(float))
X_train, X_test, y_train, y_test = train_test_split( X1, y1, test_size=0.2, random_state=4)

# %%
# to find optimal value of k 

error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(X_train,y_train)
 pred_i = knn.predict(X_test)
 error_rate.append(np.mean(pred_i != y_test))
plt.figure(figsize=(20,8))
plt.plot(range(1,40),error_rate,color='blue', linestyle='solid', 
         marker='',markerfacecolor='', markersize=15)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# Minimum error:- 0.29572758244086916 at K = 34

# %%
# ploting accuracy Vs K values
def get_K(XX_train,XX_test,yy_train,yy_test):
  acc = []
  # Will take some time
  from sklearn import metrics
  for i in range(1,40):
      neigh = KNeighborsClassifier(n_neighbors = i).fit(XX_train,yy_train)
      yhat = neigh.predict(XX_test)
      acc.append(metrics.accuracy_score(yy_test, yhat))

  #print("Maximum accuracy:-",max(acc),"at K =",acc.index(max(acc)))
  Max=max(acc)
  p=acc.index(Max)
  """plt.figure(figsize=(20,8))
  plt.plot(range(1,40),acc,color = 'blue',linestyle='solid', 
          marker='',markerfacecolor='black', markersize=20,linewidth=2.0)
  plt.title('accuracy vs. K Value')
  plt.xlabel('K')
  plt.ylabel('Accuracy')"""
  return p

# %%
X=CS_BOW['Cos_sim_bow']
y=CS_BOW['Check']
X1=X[np.newaxis,:]
y1=y[np.newaxis,:]
X1=X1.reshape(-1,1)
y1=y1.reshape(-1,1)

X1 =StandardScaler().fit(X1).transform(X1.astype(float))
X_train, X_test, y_train, y_test = train_test_split( X1, y1, test_size=0.2, random_state=4)
k=get_K(X_train,X_test,y_train,y_test)
#Train Model and Predict

neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
Pred_y = neigh.predict(X_test)
print("Accuracy of model at k is",metrics.accuracy_score(y_test, Pred_y))
print("Value of K :",k)
# Out:
# Accuracy of model at k is 0.7738927738927739
# Value of K : 18

# %%
CS_BOW
# Out:
#       Check  Cos_sim_bow
# 0         1     0.600000
# 1         1     0.680414
# 2         0     0.730297
# 3         1     0.833333
# 4         1     0.816497
# ...     ...          ...
# 2137      1     0.730297
# 2138      1     0.577350
# 2139      0     0.338062
# 2140      1     0.894427
# 2141      1     0.577350
#
# [2142 rows x 2 columns]

# %%
mean_0,mean_1 =0.447214,0.666667
incr = (mean_1 - mean_0) /100
print(incr)
alpha_list=[]
for i in range(100):
  alpha_list.append(mean_0 + i* incr)
print(alpha_list)
# Out:
# 0.00219453
# [0.447214, 0.44940853000000003, 0.45160306, 0.45379759, 0.45599212, 0.45818665000000003, 0.46038118, 0.46257571, 0.46477024, 0.46696477000000003, 0.4691593, 0.47135383, 0.47354836, 0.47574289000000003, 0.47793742, 0.48013195, 0.48232648, 0.48452101000000003, 0.48671554, 0.48891007, 0.4911046, 0.49329913000000003, 0.49549366, 0.49768819, 0.49988272, 0.50207725, 0.5042717800000001, 0.50646631, 0.50866084, 0.51085537, 0.5130499, 0.51524443, 0.51743896, 0.51963349, 0.5218280200000001, 0.52402255, 0.52621708, 0.52841161, 0.53060614, 0.53280067, 0.5349952, 0.53718973, 0.5393842600000001, 0.54157879, 0.54377332, 0.54596785, 0.54816238, 0.55035691, 0.55255144, 0.55474597, 0.5569405000000001, 0.55913503, 0.56132956, 0.56352409, 0.56571862, 0.56791315, 0.57010768, 0.57230221, 0.5744967400000001, 0.57669127, 0.5788858, 0.58108033, 0.58327486, 0.58546939, 0.58766392, 0.58985845, 0.5920529800000001, 0.59424751, 0.59644204, 0.59863657, 0.6008311, 0.60302563, 0.60522016, 0.60741469, 0.6096092200000001, 0.61180375, 0.61399828, 0.61619281, 0.61838734, 0.62058187, 0.6227764, 0.62497093, 0.6271654600000001, 0.62935999, 0.63155452, 0.63374905, 0.63594358, 0.63813811, 0.64033264, 0.64252717, 0.6447217000000001, 0.64691623, 0.64911076, 0.65130529, 0.65349982, 0.65569435, 0.65788888, 0.66008341, 0.6622779400000001, 0.66447247]

# %%
# making new function make new target variables
def new_labels(measure,threshold):
  if measure > threshold:
    return measure
  else:
    return 0
count = 1
for j in alpha_list:
  CS_BOW[count]=CS_BOW['Cos_sim_bow'].apply(lambda x:new_labels(x,j))  
  count +=1
  
CS_BOW
# Out:
#       Check  Cos_sim_bow         1         2         3         4         5  \
# 0         1     0.600000  0.600000  0.600000  0.600000  0.600000  0.600000
# 1         1     0.680414  0.680414  0.680414  0.680414  0.680414  0.680414
# 2         0     0.730297  0.730297  0.730297  0.730297  0.730297  0.730297
# 3         1     0.833333  0.833333  0.833333  0.833333  0.833333  0.833333
# 4         1     0.816497  0.816497  0.816497  0.816497  0.816497  0.816497
# ...     ...          ...       ...       ...       ...       ...       ...
# 2137      1     0.730297  0.730297  0.730297  0.730297  0.730297  0.730297
# 2138      1     0.577350  0.577350  0.577350  0.577350  0.577350  0.577350
# 2139      0     0.338062  0.000000  0.000000  0.000000  0.000000  0.000000
# 2140      1     0.894427  0.894427  0.894427  0.894427  0.894427  0.894427
# 2141      1     0.577350  0.577350  0.577350  0.577350  0.577350  0.577350
#
#              6         7         8  ...        91        92        93  \
# 0     0.600000  0.600000  0.600000  ...  0.000000  0.000000  0.000000
# 1     0.680414  0.680414  0.680414  ...  0.680414  0.680414  0.680414
# 2     0.730297  0.730297  0.730297  ...  0.730297  0.730297  0.730297
# 3     0.833333  0.833333  0.833333  ...  0.833333  0.833333  0.833333
# 4     0.816497  0.816497  0.816497  ...  0.816497  0.816497  0.816497
# ...        ...       ...       ...  ...       ...       ...       ...
# 2137  0.730297  0.730297  0.730297  ...  0.730297  0.730297  0.730297
# 2138  0.577350  0.577350  0.577350  ...  0.000000  0.000000  0.000000
# 2139  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2140  0.894427  0.894427  0.894427  ...  0.894427  0.894427  0.894427
# 2141  0.577350  0.577350  0.577350  ...  0.000000  0.000000  0.000000
#
#             94        95        96        97        98        99       100
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.680414  0.680414  0.680414  0.680414  0.680414  0.680414  0.680414
# 2     0.730297  0.730297  0.730297  0.730297  0.730297  0.730297  0.730297
# 3     0.833333  0.833333  0.833333  0.833333  0.833333  0.833333  0.833333
# 4     0.816497  0.816497  0.816497  0.816497  0.816497  0.816497  0.816497
# ...        ...       ...       ...       ...       ...       ...       ...
# 2137  0.730297  0.730297  0.730297  0.730297  0.730297  0.730297  0.730297
# 2138  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2139  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2140  0.894427  0.894427  0.894427  0.894427  0.894427  0.894427  0.894427
# 2141  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [2142 rows x 102 columns]

# %%
acc=[]
for i in range(1,101):
  X=CS_BOW[i]
  y=CS_BOW['Check']
  X1=X[np.newaxis,:]
  y1=y[np.newaxis,:]
  X1=X1.reshape(-1,1)
  y1=y1.reshape(-1,1)

  X1 =StandardScaler().fit(X1).transform(X1.astype(float))
  X_train, X_test, y_train, y_test = train_test_split( X1, y1, test_size=0.2, random_state=4)
  k=get_K(X_train,X_test,y_train,y_test)
  #Train Model and Predict
  neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
  Pred_y = neigh.predict(X_test)
  acc.append(metrics.accuracy_score(y_test, Pred_y))
  #print("Accuracy of model at k is",metrics.accuracy_score(y_test, Pred_y))

# %%
plt.rcParams.update({'font.size': 30,'axes.edgecolor' : "black" ,"axes.linewidth":5})

plt.figure(figsize=(30,12))
plt.plot(alpha_list,acc,color='blue', linestyle='solid', 
         marker='',markerfacecolor='', markersize=10,linewidth=8.0) 
#plt.title('Accuracy vs. Threshold Value of Shepard Similarity Using TF-IDF feature')
plt.xlabel('Threshold Value',fontsize=40)
plt.ylabel('Accuracy',fontsize=40)
sns.despine()
plt.show()
